# %%
import pandas as pd
df= pd.read_csv("vinatis_data_with_image_urls.csv")
import ast

# %%
# Ajout du préfixe à la colonne 'image'
df['image_url'] = "https://www.vinatis.com/" + df['image'].astype(str)

# Affichage des 5 premières URLs générées
print(df[['image', 'image_url']].head())

# Optionnel : sauvegarde dans un nouveau CSV
# df.to_csv("vinatis_data_with_image_urls.csv", index=False
# Out:
#                                                image  \
# 0  98223-fine_default/sunrose-ile-de-beaute-2024.png
# 1  94492-fine_default/colombard-sauvignon-2024-ho...
# 2  95769-fine_default/le-bal-des-papillons-2024-h...
# 3  98180-fine_default/n3-colombard-sauvignon-blan...
# 4  97174-fine_default/bandol-les-adrets-rose-2024...
#
#                                            image_url
# 0  https://www.vinatis.com/98223-fine_default/sun...
# 1  https://www.vinatis.com/94492-fine_default/col...
# 2  https://www.vinatis.com/95769-fine_default/le-...
# 3  https://www.vinatis.com/98180-fine_default/n3-...
# 4  https://www.vinatis.com/97174-fine_default/ban...

# %%
df.columns
# Out:
# Index(['other_products', 'features', 'advanced_stock_management', 'contenance',
#        'indice_comportementale', 'id', 'affichage_special_pack', 'disponible',
#        'image', 'accroche', 'franco', 'weight', 'active', 'id_manufacturer',
#        'nbvote_product', 'cuvee_type', 'achat_oneshot', 'labels',
#        'online_only', 'id_product_redirected', 'suivi', 'note_sur_20', 'name',
#        'prix_propriete', 'cache_is_pack', 'is_virtual', 'out_of_stock',
#        'note_product', 'additional_shipping_cost', 'best_sales', 'physique',
#        'allocation_annuelle', 'description', 'stocks', 'id_cuvee',
#        'minimal_quantity', 'animations', 'quantity_max', 'categories',
#        'libelle_prix_propriete', 'last_date_visibility_active', 'link_rewrite',
#        'active_description', 'nous_contacter', 'buy_by_multiple',
#        'available_for_order', 'manufacturer_name', 'no_animation', 'date_add',
#        'description_short', 'abv', 'cuvee_type_name', 'subtitle_with_link',
#        'comment', 'providers', 'subtitle_without_link', 'prices',
#        'pricePerLiter', 'rewards', 'nutritional_data', 'id_stock_booked',
#        'image_url'],
#       dtype='object')

# %%
df.head()
# Out:
#                                       other_products  \
# 0  [{'id_image': 98223, 'vintage': 2024, 'id': 75...
# 1  [{'id_image': 94492, 'vintage': 2024, 'id': 72...
# 2  [{'id_image': 95769, 'vintage': 2024, 'id': 73...
# 3  [{'id_image': 98180, 'vintage': 2024, 'id': 75...
# 4  [{'id_image': 97174, 'vintage': 2024, 'id': 74...
#
#                                             features  \
# 0  {'emballage_d_origine': 'AUCUN', 'country': 'F...
# 1  {'emballage_d_origine': 'AUCUN', 'country': 'F...
# 2  {'country': 'France', 'allergen': False, 'tast...
# 3  {'country': 'France', 'allergen': False, 'tast...
# 4  {'country': 'France', 'allergen': False, 'tast...
#
#    advanced_stock_management  contenance  indice_comportementale     id  \
# 0                          0        0.75                      38  75264
# 1                          0        0.75                      37  72739
# 2                          0        0.75                      37  73560
# 3                          0        0.75                      37  75247
# 4                          0        0.75                      36  74531
#
#    affichage_special_pack  disponible  \
# 0                   False        1531
# 1                   False       12518
# 2                   False        3397
# 3                   False        6807
# 4                   False         899
#
#                                                image  \
# 0  98223-fine_default/sunrose-ile-de-beaute-2024.png
# 1  94492-fine_default/colombard-sauvignon-2024-ho...
# 2  95769-fine_default/le-bal-des-papillons-2024-h...
# 3  98180-fine_default/n3-colombard-sauvignon-blan...
# 4  97174-fine_default/bandol-les-adrets-rose-2024...
#
#                                             accroche  ...  \
# 0  Le rosé corse par excellence ! Vif et aromatiq...  ...
# 1  Savoureux <a class="maillage" href ="/vin-d-ho...  ...
# 2  Plongez dans un univers de légèreté et d’éléga...  ...
# 3  La référence incontestable des Côtes de <a cla...  ...
# 4  Une pépite de Bandol signée Moulin de la Roque...  ...
#
#                                   subtitle_with_link  \
# 0  <a class="maillage" href ="/achat-vin-corse">C...
# 1  <a class="maillage" href ="/achat-vin-sud-oues...
# 2  <a class="maillage" href ="/achat-vin-sud-oues...
# 3  <a class="maillage" href ="/achat-vin-sud-oues...
# 4  <a class="maillage" href ="/achat-vin-provence...
#
#                                              comment  providers  \
# 0  {'date_add': '2025-03-12 13:59:50', 'wineWaite...     [3866]
# 1  {'date_add': '2025-04-24 08:16:16', 'wineWaite...      [659]
# 2  {'date_add': '2025-05-11 21:28:22', 'wineWaite...      [659]
# 3  {'date_add': '2025-05-06 16:37:28', 'wineWaite...      [253]
# 4  {'date_add': '2025-03-10 18:33:51', 'wineWaite...      [687]
#
#                      subtitle_without_link  \
# 0                Corse / Ile de Beauté IGP
# 1        Sud-Ouest / Côtes de Gascogne IGP
# 2        Sud-Ouest / Côtes de Gascogne IGP
# 3        Sud-Ouest / Côtes de Gascogne IGP
# 4  Provence-Alpes-Côte d'Azur / Bandol AOC
#
#                                               prices  pricePerLiter  \
# 0  {'discount_quantities': [2], 'best_promo': 15,...          10.27
# 1  {'discount_quantities': [6], 'best_promo': 15,...           8.80
# 2  {'discount_quantities': [6], 'best_promo': 15,...          11.47
# 3  {'discount_quantities': [6], 'best_promo': 12,...           8.67
# 4  {'discount_quantities': [2], 'best_promo': 10,...          17.60
#
#                                              rewards nutritional_data  \
# 0                                                NaN              NaN
# 1  {'flatened': [606, 3138], 'wrapped_ids': [53, ...              NaN
# 2  {'flatened': [606], 'wrapped_ids': [53], 'ids'...              NaN
# 3  {'flatened': [606, 3138], 'wrapped_ids': [53, ...              NaN
# 4                                                NaN              NaN
#
#    id_stock_booked                                          image_url
# 0              NaN  https://www.vinatis.com/98223-fine_default/sun...
# 1              NaN  https://www.vinatis.com/94492-fine_default/col...
# 2              NaN  https://www.vinatis.com/95769-fine_default/le-...
# 3              NaN  https://www.vinatis.com/98180-fine_default/n3-...
# 4              NaN  https://www.vinatis.com/97174-fine_default/ban...
#
# [5 rows x 62 columns]

# %%
def safe_literal_eval(val):
    if pd.isna(val):
        return {}
    try:
        return ast.literal_eval(val)
    except (ValueError, SyntaxError):
        return {}

def flatten_dict_columns(df, columns):
    for col in columns:
        # Convertir en dict de manière sûre
        df[col] = df[col].apply(safe_literal_eval)
        # Aplatir et préfixer
        flat = pd.json_normalize(df[col]).add_prefix(f'{col}_')
        df = pd.concat([df.drop(columns=[col]), flat], axis=1)
    return df

# Utilisation :
cols_to_flatten = ['features','prices','comment','other_products',]  # Ajoute les colonnes à aplatir
df = flatten_dict_columns(df, cols_to_flatten)
df.head()
# Out:
#    advanced_stock_management  contenance  indice_comportementale     id  \
# 0                          0        0.75                      38  75264
# 1                          0        0.75                      37  72739
# 2                          0        0.75                      37  73560
# 3                          0        0.75                      37  75247
# 4                          0        0.75                      36  74531
#
#    affichage_special_pack  disponible  \
# 0                   False        1531
# 1                   False       12518
# 2                   False        3397
# 3                   False        6807
# 4                   False         899
#
#                                                image  \
# 0  98223-fine_default/sunrose-ile-de-beaute-2024.png
# 1  94492-fine_default/colombard-sauvignon-2024-ho...
# 2  95769-fine_default/le-bal-des-papillons-2024-h...
# 3  98180-fine_default/n3-colombard-sauvignon-blan...
# 4  97174-fine_default/bandol-les-adrets-rose-2024...
#
#                                             accroche  franco  weight  ...  \
# 0  Le rosé corse par excellence ! Vif et aromatiq...   False    1.28  ...
# 1  Savoureux <a class="maillage" href ="/vin-d-ho...   False    1.18  ...
# 2  Plongez dans un univers de légèreté et d’éléga...    True    1.19  ...
# 3  La référence incontestable des Côtes de <a cla...   False    1.15  ...
# 4  Une pépite de Bandol signée Moulin de la Roque...    True    1.12  ...
#
#                                      comment_content  comment_source_shop  \
# 0  Frais, fruité et bien équilibré, ce rosé corse...                  0.0
# 1  Vin sec et fruité. Un nez très porté sur les a...                  0.0
# 2  On adore. Mi vif, mi liquoreux. Le nez est sur...                  0.0
# 3  Le plaisir du fruit avec le Colombard et une g...                  0.0
# 4  Un Bandol parfaitement équilibré, à la fois fr...                  0.0
#
#                                     other_products_0  \
# 0  {'id_image': 98223, 'vintage': 2024, 'id': 752...
# 1  {'id_image': 94492, 'vintage': 2024, 'id': 727...
# 2  {'id_image': 95769, 'vintage': 2024, 'id': 735...
# 3  {'id_image': 98180, 'vintage': 2024, 'id': 752...
# 4  {'id_image': 97174, 'vintage': 2024, 'id': 745...
#
#                                     other_products_1  other_products_2  \
# 0  {'id_image': 100873, 'vintage': 2024, 'id': 77...              None
# 1                                               None              None
# 2                                               None              None
# 3                                               None              None
# 4                                               None              None
#
#   other_products_3  other_products_4  other_products_5  other_products_6  \
# 0             None              None              None              None
# 1             None              None              None              None
# 2             None              None              None              None
# 3             None              None              None              None
# 4             None              None              None              None
#
#    other_products_7
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None
#
# [5 rows x 127 columns]

# %%
list(df.columns)
# Out:
# ['advanced_stock_management',
#  'contenance',
#  'indice_comportementale',
#  'id',
#  'affichage_special_pack',
#  'disponible',
#  'image',
#  'accroche',
#  'franco',
#  'weight',
#  'active',
#  'id_manufacturer',
#  'nbvote_product',
#  'cuvee_type',
#  'achat_oneshot',
#  'labels',
#  'online_only',
#  'id_product_redirected',
#  'suivi',
#  'note_sur_20',
#  'name',
#  'prix_propriete',
#  'cache_is_pack',
#  'is_virtual',
#  'out_of_stock',
#  'note_product',
#  'additional_shipping_cost',
#  'best_sales',
#  'physique',
#  'allocation_annuelle',
#  'description',
#  'stocks',
#  'id_cuvee',
#  'minimal_quantity',
#  'animations',
#  'quantity_max',
#  'categories',
#  'libelle_prix_propriete',
#  'last_date_visibility_active',
#  'link_rewrite',
#  'active_description',
#  'nous_contacter',
#  'buy_by_multiple',
#  'available_for_order',
#  'manufacturer_name',
#  'no_animation',
#  'date_add',
#  'description_short',
#  'abv',
#  'cuvee_type_name',
#  'subtitle_with_link',
#  'providers',
#  'subtitle_without_link',
#  'pricePerLiter',
#  'rewards',
#  'nutritional_data',
#  'id_stock_booked',
#  'image_url',
#  'features_emballage_d_origine',
#  'features_country',
#  'features_allergen',
#  'features_taste',
#  'features_food_and_wine_matching',
#  'features_recommended_with',
#  'features_type',
#  'features_smell',
#  'features_service_temperature',
#  'features_capacity',
#  'features_flatened',
#  'features_colour',
#  'features_character',
#  'features_abv',
#  'features_vintage',
#  'features_service',
#  'features_storage_instructions',
#  'features_sight',
#  'features_sortable_vintage',
#  'features_appellation',
#  'features_region',
#  'features_taste_style',
#  'features_appellation_type',
#  'features_all_grapes',
#  'features_grape_variety',
#  'features_to_drink_until',
#  'features_bottle_stopper',
#  'features_pictos',
#  'features_images',
#  'features_full_grape_variety',
#  'features_bio',
#  'features_to_drink_from',
#  'features_type_coffret',
#  'features_wine_classification',
#  'features_fine_wine',
#  'features_champagne_type',
#  'features_whisky_style',
#  'features_spirits_type',
#  'features_nombre_de_bouteilles',
#  'features_beer_type',
#  'prices_discount_quantities',
#  'prices_best_promo',
#  'prices_best_conditionnement',
#  'prices_manuel',
#  'prices_salable',
#  'prices_isVF',
#  'prices_is_country_restricted',
#  'prices_promotions',
#  'prices_id_country',
#  'prices_price',
#  'prices_is_group_restricted',
#  'prices_isPP',
#  'prices_id_group',
#  'prices_best_price',
#  'comment_date_add',
#  'comment_wineWaiter',
#  'comment_note_sur_20',
#  'comment_source_domain',
#  'comment_customer_name',
#  'comment_content',
#  'comment_source_shop',
#  'other_products_0',
#  'other_products_1',
#  'other_products_2',
#  'other_products_3',
#  'other_products_4',
#  'other_products_5',
#  'other_products_6',
#  'other_products_7']

# %%
df.describe()
# Out:
#        advanced_stock_management   contenance  indice_comportementale  \
# count                     5074.0  5074.000000             5074.000000
# mean                         0.0     0.938279               11.453291
# std                          0.0     0.720197                7.844907
# min                          0.0     0.250000                1.000000
# 25%                          0.0     0.750000                4.000000
# 50%                          0.0     0.750000               11.000000
# 75%                          0.0     0.750000               16.000000
# max                          0.0     9.000000               38.000000
#
#                  id    disponible       weight  id_manufacturer  \
# count   5074.000000   5074.000000  5074.000000      5074.000000
# mean   66704.153922    201.298975     1.638082      1907.449744
# std    11517.678767    546.741589     1.274517      1357.511916
# min      742.000000    -71.000000     0.490000         0.000000
# 25%    64413.500000     18.000000     1.260000       447.000000
# 50%    70503.500000     61.000000     1.320000      1863.000000
# 75%    73798.750000    193.000000     1.400000      3058.000000
# max    77976.000000  12518.000000    22.810000      4298.000000
#
#        nbvote_product   cuvee_type  achat_oneshot  ...  \
# count     5074.000000  5074.000000    5074.000000  ...
# mean         5.019314     2.584549       0.021088  ...
# std         13.802071     0.819897       0.143692  ...
# min          0.000000     0.000000       0.000000  ...
# 25%          0.000000     2.000000       0.000000  ...
# 50%          1.000000     3.000000       0.000000  ...
# 75%          4.000000     3.000000       0.000000  ...
# max        247.000000     8.000000       1.000000  ...
#
#        features_to_drink_until  features_to_drink_from  prices_best_promo  \
# count              3983.000000              164.000000        5074.000000
# mean               2033.577203             2021.932927           5.858691
# std                   7.540815                3.423361           7.847473
# min                2025.000000             2012.000000         -29.000000
# 25%                2029.000000             2019.750000           0.000000
# 50%                2031.000000             2021.000000           0.000000
# 75%                2036.000000             2024.000000          14.000000
# max                2080.000000             2034.000000          33.000000
#
#        prices_best_conditionnement  prices_id_country  prices_price  \
# count                  5074.000000             5074.0   5074.000000
# mean                      1.403823                8.0     75.775897
# std                       0.820779                0.0    767.430657
# min                       1.000000                8.0      4.900000
# 25%                       1.000000                8.0     14.500000
# 50%                       1.000000                8.0     25.450000
# 75%                       2.000000                8.0     50.000000
# max                      12.000000                8.0  43000.000000
#
#        prices_id_group  prices_best_price  comment_note_sur_20  \
# count           5074.0        5074.000000          2038.000000
# mean               3.0          74.377300            18.121688
# std                0.0         767.459402             0.742768
# min                3.0           4.500360            10.000000
# 25%                3.0          12.949825            18.000000
# 50%                3.0          24.500750            18.000000
# 75%                3.0          48.999600            19.000000
# max                3.0       43000.000000            20.000000
#
#        comment_source_shop
# count          3913.000000
# mean              0.160746
# std               0.781282
# min               0.000000
# 25%               0.000000
# 50%               0.000000
# 75%               0.000000
# max               6.000000
#
# [8 rows x 39 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5074 entries, 0 to 5073
# Columns: 127 entries, advanced_stock_management to other_products_7
# dtypes: bool(18), float64(17), int64(22), object(70)
# memory usage: 4.3+ MB

# %%
# Sauvegarde du DataFrame au format CSV
df.to_csv('vins_vinatis_flat_complet.csv', index=False)
